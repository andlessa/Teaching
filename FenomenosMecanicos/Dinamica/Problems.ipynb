# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy

from matplotlib import animation, rc
from IPython.display import HTML
rc('animation', html='jshtml')
import seaborn as sns

#Define plotting style:
sns.set() #Set style
sns.set_style('ticks',{'font.family':'serif', 'font.serif':'Times New Roman'})
sns.set_context('paper', font_scale=2.2)
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ## Problema 1 (Air Hockey)

# %% [markdown]
# <font size=3px>Um disco de massa $m = 200$ g está em repouso no centro de uma mesa quadrada de air hockey de lado $l = 2$ m. O disco é atingido por uma raquete na direção de $\theta = 30^{\circ}$ com a horizontal. Se o tempo de contato entre a raquete e o disco é de $\Delta t = 0,1$ s e a força exercida durante o contato foi de 1 N, determine a trajetória do disco:<br>
#     a) Durante o contato com a raquete<br>
#     b) Após o contato<br>
#     c) Em que instante o disco atingirá uma das laterais da mesa?
# </font>

# %%
fig = plt.figure()
t0  = 0.
tC = 0.1
v0x, v0y = 0.,0.
x0,y0 = 1.,1.
a = 1./0.2
theta = 30.*np.pi/180.
l = 2.

ax = a*np.cos(theta)
ay = a*np.sin(theta)
v1x = v0x + ax*tC
v1y = v0y + ay*tC
x1 = x0 + v0x*tC + (ax*tC**2)/2.
y1 = y0 + v0y*tC + (ay*tC**2)/2.
xF = lambda t: x0 + v0x*t + (ax*t**2)/2. if t <= tC else x1 + v1x*(t-tC)
yF = lambda t: y0 + v0y*t + (ay*t**2)/2. if t <= tC else y1 + v1y*(t-tC)

print('ax = %1.2f m/s^2, ay = %1.2f m/s^2, v1x = %1.2f m/s, v1y = %1.2f m/s, x1 = %1.2f m, y1 = %1.2f m' %(ax,ay,v1x,v1y,x1,y1))

tmin, tmax = 0.,5.
dt = 0.05
tpts = np.linspace(tmin,tmax,100)
xPpts = [xF(t) for t in tpts]
yPpts = [yF(t) for t in tpts]

pt, = plt.plot([xF(tmin)],[yF(tmin)],'o',markersize=15)
line1, = plt.plot([xF(tmin)],[yF(tmin)],'--',linewidth=3)
vec = plt.quiver([xF(tmin)],[yF(tmin)],[np.cos(theta)],[np.sin(theta)],scale=5.5,alpha = 0.2)
plt.plot([0.,l,l,0.,0.],[0.,0.,l,l,0.],'-')
plt.xlabel(r'x (m)')
plt.ylabel(r'y (m)')
text = plt.text(0.1,0.9*l,r't = %1.2f s' %tmin)
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)


def init():
    line1.set_data([xF(tmin)],[yF(tmin)])
    pt.set_data([xF(tmin)],[yF(tmin)])
    vec.set_offsets([xF(tmin),yF(tmin)])
    text.set_text(r't = %1.2f s' %tmin)
    return (pt,line1,vec,text)
def animate(i):
    tA = tmin+i*dt
    newpts = np.linspace(tmin,tA,100)
    xPts = [xF(t) for t in newpts]
    yPts = [yF(t) for t in newpts]
    xpt,ypt = xF(newpts[-1]),yF(newpts[-1])
    pt.set_data([xpt],[ypt])
    line1.set_data(xPts,yPts)
    vec.set_offsets([xpt,ypt])
    text.set_text(r't = %1.2f s' %tA)    
    if tA > tC:
        vec.set_offsets([2*l,2*l])
        
    return (pt,line1,vec,text)


anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=int((tmax-tmin)/dt), interval=150, 
                               blit=True)
plt.close()
anim
# plt.show()
# Out:
# ax = 4.33 m/s^2, ay = 2.50 m/s^2, v1x = 0.43 m/s, v1y = 0.25 m/s, x1 = 1.02 m, y1 = 1.01 m
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img5529d4524cf24fecb74bde50102e388a">
#     <br>
#     <input id="_anim_slider5529d4524cf24fecb74bde50102e388a" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim5529d4524cf24fecb74bde50102e388a.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim5529d4524cf24fecb74bde50102e388a.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim5529d4524cf24fecb74bde50102e388a.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim5529d4524cf24fecb74bde50102e388a.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim5529d4524cf24fecb74bde50102e388a.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim5529d4524cf24fecb74bde50102e388a.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim5529d4524cf24fecb74bde50102e388a.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim5529d4524cf24fecb74bde50102e388a.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim5529d4524cf24fecb74bde50102e388a.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim5529d4524cf24fecb74bde50102e388a.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select5529d4524cf24fecb74bde50102e388a" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5529d4524cf24fecb74bde50102e388a";
#     var slider_id = "_anim_slider5529d4524cf24fecb74bde50102e388a";
#     var loop_select_id = "_anim_loop_select5529d4524cf24fecb74bde50102e388a";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3XlUFGe6BvCnaUCaTQWVRYUIQruN\
# eicmYtxwwUnU5E4A51zibvQS58pEyaJE4zKBMeIxnASHjIMxjujESYuMxiWLJlER8A7RDHFhiUYD\
# 0iIKgkBDA133Dw990zZLd9tb4fM7x3Owvq++eqtOyWPtEkEQBBAREYmMg60LICIiMgUDjIiIRIkB\
# RkREosQAIyIiUWKAERGRKDHAiIhIlBhgREQkSgwwIiISJQYYERGJEgOMiIhEiQFGRESixAAjIiJR\
# crR1AfZMLpfbugQiosdGUVGRUf0ZYF0wdoMSEZHxTDlg4ClEIiISJbs4AlOr1Thx4gQOHTqEixcv\
# oqWlBRKJBCNHjsSiRYvwzDPPGDVeVlYWMjIyoFQqIZVKMXbsWMTHx6N///4WWgMiIrI2uzgCS05O\
# xqpVqyCXy/HFF1/g3LlzOHjwIJqbm7F48WLs27fP4LFSUlKwdu1aLFmyBLm5uTh8+DDu3r2L6Oho\
# lJaWWnAtiIjImuwiwDQaDcaMGYP4+Hi4u7sDAPz9/bFt2za4uLggOTkZdXV1XY5z8eJF7NixA1FR\
# UZg9ezYAwMvLC1u2bEFtbS02btxoydUgIiIrsosAmzhxIl555RW96V5eXggKCkJjYyOuXLnS5Tj7\
# 9u2DIAiYOXOmznQfHx+MGTMG2dnZuHHjhtnqJiIi27GLAJsyZQomTpzYbltzczMAoFevXl2Ok5eX\
# BwAYNmyYXtvw4cMBADk5OaaWSUREdsQuAqwjVVVVuH79OkJDQzF48OBO+6pUKpSXl8PFxQU9e/bU\
# a/fx8QEAXLt2zSK1EhGRddnFXYgdycjIQGtrK9auXQuJRNJp39raWgCATCZrt93V1VWnnzXUqeuh\
# bm222vKIiGzFWeoEd2c3qy7TbgPs+++/R3p6OlauXImwsDCLLy81NRXbt28323h16nos/eeb0Aga\
# s41JRGSvHCQO2PnbZKuGmF0G2I8//ojY2FjMnz8fsbGxBs3j6ekJ4MGpxPY0NDTo9HtYXFwc4uLi\
# dKY9yquk1K3N0AgavBuRgF6y9pdJRNQd3FPVYs1Xm61+xsnuAqy4uBiLFy9GZGQkVq9ebfB8MpkM\
# /v7+KC8vR01Njd51sIqKCgBAUFCQWevtSi+ZJ7xkXd+AQkRExrGrmzguX76MBQsW4He/+51OeJWV\
# lWkDqDNtpxovX76s13bp0iUAMPqtHkREZJ/sJsAKCgqwaNEiLF68GK+++qpO2/bt2/Hpp59q/y4I\
# ApRKpd4Yc+fOhUQiwbFjx3SmV1RUID8/HxMmTEBgYKBlVoCIiKzKLk4hnj9/HsuWLUOfPn2gVquR\
# mpqq037lyhWd9xgmJiZi7969mD9/PtatW6edPmLECMTGxiI9PR1jx47F7NmzUV1djdWrV8PDwwMb\
# Nmyw2jqZ04kTJ3DlyhW8+OKLGDBggK3LaVddXR3+/Oc/48svv8Tt27fRu3dvTJ48GXFxcejXr5/R\
# 46nVauzcuROfffYZysrK4OHhgbCwMMTFxWHQoEEdznfmzBns3LkTly5dQmtrK0JDQzFv3jw8//zz\
# j7J6RGSH7CLAdu7cibq6OtTV1XV4J+D06dO1P/v6+kImk8HPz0+v36pVqxAYGIidO3ciKSkJDg4O\
# CAsLQ2Zmpmhf5nvixAlkZWXh6aeftssAq66uxksvvYTq6mps3boVTz31FAoLC/H666/j66+/xief\
# fIKAgACDx2tqasKSJUtw6dIlJCYmYtq0aSgtLUVCQgIiIyOxe/dujBo1Sm++vXv34p133kFkZCS2\
# bt2KHj16ID09Ha+//jouX75s1DVVIhIBgToUGhpq8rx3G6qFOftfEe42VD9yHatXr
